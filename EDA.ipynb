# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
pd.options.display.max_columns = None

# %%
data = pd.read_csv('input/HR-Employee-Attrition.csv')

# %%
attrition = data [data['Attrition']=='Yes']

# %%
data.drop(axis=1,columns=['EmployeeCount','EmployeeNumber','Over18','StandardHours'],inplace=True)

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  HourlyRate  JobInvolvement  JobLevel                JobRole  \
# ...

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810   802.485714          9.192517     2.912925
# std       9.135373   403.509100          8.106864     1.024165
# min      18.000000   102.000000          1.000000     1.000000
# 25%      30.000000   465.000000          2.000000     2.000000
# 50%      36.000000   802.000000          7.000000     3.000000
# 75%      43.000000  1157.000000         14.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1470.000000  1470.000000     1470.000000  1470.000000
# mean                  2.721769    65.891156        2.729932     2.063946
# std                   1.093082    20.329428        0.711561     1.106940
# min                   1.000000    30.000000        1.000000     1.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   object
# ...

# %%
data.shape
# Out:
# (1470, 31)

# %%
data.info
# Out:
# <bound method DataFrame.info of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
# ...

# %%
data.size
# Out:
# 45570

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# ...

# %%
data.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StockOptionLevel               4
# TotalWorkingYears             40
# TrainingTimesLastYear          7
# WorkLifeBalance                4
# YearsAtCompany                37
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
data.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# ...

# %%
data.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# MonthlyIncome             0.497855   0.007707         -0.017014   0.094961
# MonthlyRate               0.028051  -0.032182          0.027473  -0.026084
# ...

# %%
sns.countplot( x='Attrition', data=data)

# %%
sns.countplot( x='Attrition',hue= 'OverTime', data=data)

# %%
percentages = data['Attrition'].value_counts(normalize=True).plot.bar()

# %% [markdown]
# - No hay valores nulos
# - 84% no attrition

# %% [markdown]
# # Age

# %%
plt.figure(figsize=(10,5))
sns.set(style="whitegrid", palette="colorblind")
sns.histplot(x='Age', hue= 'Attrition', stat="probability" ,data=data, bins=40)

# %%
data['Age'].value_counts().sort_index()
# Out:
# 18     8
# 19     9
# 20    11
# 21    13
# 22    16
# 23    14
# 24    26
# 25    26
# 26    39
# 27    48
# 28    48
# 29    68
# 30    60
# 31    69
# 32    61
# 33    58
# 34    77
# 35    78
# 36    69
# 37    50
# 38    58
# 39    42
# 40    57
# 41    40
# 42    46
# 43    32
# 44    33
# 45    41
# 46    33
# 47    24
# 48    19
# 49    24
# 50    30
# 51    19
# 52    18
# 53    19
# 54    18
# 55    22
# 56    14
# 57     4
# 58    14
# 59    10
# 60     5
# Name: Age, dtype: int64

# %%
data['Age'].mean()
# Out:
# 36.923809523809524

# %%
plt.figure(figsize=(10,5))
sns.set(style="whitegrid", palette="colorblind")
sns.histplot(x='Age', hue= 'Attrition',data=attrition, bins=40)

# %%
attrition['Age'].value_counts().sort_index()
# Out:
# 18     4
# 19     6
# 20     6
# 21     6
# 22     5
# 23     4
# 24     7
# 25     6
# 26    12
# 27     3
# 28    14
# 29    18
# 30     9
# 31    18
# 32    11
# 33    12
# 34     9
# 35    10
# 36     6
# 37     6
# 38     2
# 39     6
# 40     5
# 41     6
# 42     2
# 43     2
# 44     6
# 45     2
# 46     4
# 47     3
# 48     2
# 49     2
# 50     5
# 51     2
# 52     3
# 53     2
# 55     3
# 56     3
# 58     5
# Name: Age, dtype: int64

# %% [markdown]
# # Business Travel

# %%
data['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
sns.countplot(data=data, x='BusinessTravel', hue = 'Attrition')

# %%
sns.countplot(data=attrition, x='BusinessTravel', hue = 'Attrition')

# %%
from sklearn.preprocessing import OneHotEncoder, LabelBinarizer
oe = LabelBinarizer()
bussiness_travel = oe.fit_transform(data['BusinessTravel'])

# %%
print(bussiness_travel)
# Out:
# [[0 0 1]
#  [0 1 0]
#  [0 0 1]
#  ...
#  [0 0 1]
#  [0 1 0]
#  [0 0 1]]

# %% [markdown]
# # Daily Rate

# %%
data['DailyRate'].hist()

# %%
sns.histplot(data=data, x='DailyRate', hue='Attrition')

# %%
sns.histplot(data=attrition, x='DailyRate', hue='Attrition')

# %% [markdown]
# # Department

# %%
sns.countplot(data=data, x='Department',hue='Attrition')

# %% [markdown]
# # Distance from home

# %%
sns.histplot(data=data, x='DistanceFromHome', hue='Attrition')

# %%
sns.histplot(data=attrition, x='DistanceFromHome', hue='Attrition')

# %% [markdown]
# # Education

# %%
sns.countplot(data=data, x='Education', hue='Attrition')

# %%
sns.countplot(data=attrition, x='Education', hue='Attrition')

# %% [markdown]
# # Education Field

# %%
EF = sns.countplot(data=data, x='EducationField', hue='Attrition')
for item in EF.get_xticklabels():
    item.set_rotation(45)

# %%
EF = sns.countplot(data=attrition, x='EducationField', hue='Attrition')
for item in EF.get_xticklabels():
    item.set_rotation(45)

# %% [markdown]
# # EnvironmentSatisfaction

# %%
ES = sns.countplot(data=data, x='EnvironmentSatisfaction', hue='Attrition')

# %%
ES = sns.countplot(data=attrition, x='EnvironmentSatisfaction', hue='Attrition')

# %% [markdown]
# # Gender

# %%
G = sns.countplot(data=data, x='Gender', hue='Attrition')

# %%
sns.countplot(data=attrition, x='Gender', hue='Attrition')

# %% [markdown]
# # HourlyRate

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=data, x='HourlyRate', hue='Attrition')

# %%
sns.histplot(data=attrition, x='HourlyRate', hue='Attrition')

# %% [markdown]
# # JobInvolvement

# %%
sns.countplot(data=data, x='JobInvolvement', hue='Attrition')

# %%
sns.countplot(data=attrition, x='JobInvolvement', hue='Attrition')

# %% [markdown]
# # JobLevel

# %%
sns.countplot(data=data, x='JobLevel', hue='Attrition')

# %%
sns.countplot(data=attrition, x='JobLevel', hue='Attrition')

# %% [markdown]
# # JobRole

# %%
plt.figure(figsize=(10,5))
JR=sns.countplot(data=data, x='JobRole', hue='Attrition')
for item in JR.get_xticklabels():
    item.set_rotation(45)

# %%
plt.figure(figsize=(10,5))
JR= sns.countplot(data=attrition, x='JobRole', hue='Attrition')
for item in JR.get_xticklabels():
    item.set_rotation(80)

# %%
# JobSatisfaction

# %%
sns.countplot(data=data, x='JobSatisfaction', hue='Attrition')

# %%
sns.countplot(data=attrition, x='JobSatisfaction', hue='Attrition')

# %%
# MaritalStatus

# %%
sns.countplot(data=data, x='MaritalStatus', hue='Attrition')

# %%
sns.countplot(data=attrition, x='MaritalStatus', hue='Attrition')

# %%
# MonthlyIncome

# %%
sns.histplot(data=data, x='MonthlyIncome', hue='Attrition')

# %%
sns.histplot(data=attrition, x='MonthlyIncome', hue='Attrition')

# %%
# MonthlyRate

# %%
sns.histplot(data=data, x='MonthlyRate', hue='Attrition')

# %%
sns.histplot(data=attrition, x='MonthlyRate', hue='Attrition')

# %%
# NumCompaniesWorked

# %%
sns.countplot(data=data, x='NumCompaniesWorked', hue='Attrition')

# %%
sns.countplot(data=attrition, x='NumCompaniesWorked', hue='Attrition')

# %%
# OverTime

# %%
sns.countplot(data=data, x='OverTime', hue='Attrition')

# %%
sns.countplot(data=attrition, x='OverTime', hue='Attrition')

# %%
# PercentSalaryHike

# %%
sns.histplot(data=data, x='PercentSalaryHike', hue='Attrition')

# %%
sns.histplot(data=attrition, x='PercentSalaryHike', hue='Attrition')

# %%
# PerformanceRating

# %%
sns.countplot(data=data, x='PerformanceRating', hue='Attrition')

# %%
sns.countplot(data=attrition, x='PerformanceRating', hue='Attrition')

# %%
# RelationshipSatisfaction

# %%
sns.countplot(data=data, x='RelationshipSatisfaction', hue='Attrition')

# %%
sns.countplot(data=attrition, x='PerformanceRating', hue='Attrition')

# %%
# StockOptionLevel

# %%
sns.countplot(data=data, x='StockOptionLevel', hue='Attrition')

# %%
sns.countplot(data=attrition, x='StockOptionLevel', hue='Attrition')

# %%
# TotalWorkingYears

# %%
sns.histplot(data=data, x='TotalWorkingYears', hue='Attrition')

# %%
sns.histplot(data=attrition, x='TotalWorkingYears', hue='Attrition')

# %%
# TrainingTimesLastYear

# %%
sns.countplot(data=data, x='TrainingTimesLastYear', hue='Attrition')

# %%
sns.countplot(data=attrition, x='TrainingTimesLastYear', hue='Attrition')

# %%
# WorkLifeBalance

# %%
sns.countplot(data=data, x='WorkLifeBalance', hue='Attrition')

# %%
sns.countplot(data=attrition, x='TrainingTimesLastYear', hue='Attrition')

# %%
# YearsAtCompany

# %%
sns.histplot(data=data, x='YearsAtCompany', hue='Attrition')

# %%
sns.histplot(data=attrition, x='YearsAtCompany', hue='Attrition')

# %%
# YearsInCurrentRole

# %%
sns.histplot(data=data, x='YearsInCurrentRole', hue='Attrition')

# %%
sns.histplot(data=attrition, x='YearsInCurrentRole', hue='Attrition')

# %%
# YearsSinceLastPromotion

# %%
sns.countplot(data=data, x='YearsSinceLastPromotion', hue='Attrition')

# %%
sns.countplot(data=attrition, x='YearsSinceLastPromotion', hue='Attrition')

# %%
# YearsWithCurrManager

# %%
sns.countplot(data=data, x='YearsWithCurrManager', hue='Attrition')

# %%
sns.countplot(data=attrition, x='YearsWithCurrManager', hue='Attrition')
